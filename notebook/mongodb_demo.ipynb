# %%
print("oky")
# Out:
# oky

# %%
""" mongodb+srv://TINTUEEECEC:TINTUEEECEC@cluster0.fhypued.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0 """

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv(r"Visadataset.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44444,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 122996.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV04',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 98,
#   'yr_of_estab': 1897,
#   'region_of_employment': 'West',
#   'prevailing_wage': 83434.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV05',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1082,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 149907.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV06',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2339,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'South',
#   'prevailing_wage': 78252.14,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV07',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4985,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'South',
#   'prevailing_wage': 53635.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV08',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3035,
#   'yr_of_estab': 1924,
#   'region_of_employment': 'West',
#   'prevailing_wage': 418.2298,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV09',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4810,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 74362.19,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV10',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2251,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 67514.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV11',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2465,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 83588.56,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV12',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4069,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 70813.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV13',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 123876,
#   'yr_of_estab': 1963,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 28663.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV14',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1652,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 107196.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV15',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 15756,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'South',
#   'prevailing_wage': 220081.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV16',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4897,
#   'yr_of_estab': 1987,
#   'region_of_employment': 'West',
#   'prevailing_wage': 74108.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV17',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 76638,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 3706.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV18',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2747,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 16132.61,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV19',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4743,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 150441.13,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV20',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 843,
#   'yr_of_estab': 1972,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 79948.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV21',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 880,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 71128.98,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV22',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1706,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 137694.98,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV23',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2878,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'West',
#   'prevailing_wage': 45642.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV24',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1517,
#   'yr_of_estab': 1884,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 90108.38,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV25',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 241,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 71286.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV26',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1100,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 99489.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV27',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 756,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 86332.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV28',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2889,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 103029.33,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV29',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 18,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 40925.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV30',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 758,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 189190.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV31',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1408,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 79594.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV32',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 995,
#   'yr_of_estab': 1880,
#   'region_of_employment': 'South',
#   'prevailing_wage': 135866.13,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV33',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2415,
#   'yr_of_estab': 1963,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 72077.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV34',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2395,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'South',
#   'prevailing_wage': 81921.18,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV35',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1809,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'South',
#   'prevailing_wage': 225569.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV36',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5512,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 92421.92,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV37',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2520,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 2490.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV38',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44,
#   'yr_of_estab': 1965,
#   'region_of_employment': 'South',
#   'prevailing_wage': 110817.26,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV39',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2206,
#   'yr_of_estab': 1909,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 50960.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV40',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3729,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 125336.9,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV41',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3723,
#   'yr_of_estab': 2011,
#   'region_of_employment': 'West',
#   'prevailing_wage': 39633.32,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV42',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1209,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 156326.33,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV43',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 19770,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 43630.58,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV44',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2582,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'South',
#   'prevailing_wage': 54614.42,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV45',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5407,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 28989.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV46',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2092,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'South',
#   'prevailing_wage': 22924.91,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV47',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2623,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'South',
#   'prevailing_wage': 61567.75,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV48',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 226,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 156251.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV49',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2405,
#   'yr_of_estab': 1933,
#   'region_of_employment': 'South',
#   'prevailing_wage': 86022.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV50',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2171,
#   'yr_of_estab': 1960,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 49565.37,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV51',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 746,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 66191.41,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV52',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3129,
#   'yr_of_estab': 2003,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 95623.2,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV53',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1647,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 115014.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV54',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2438,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 35018.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV55',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 11733,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 230.8072,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV56',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2368,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 113799.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV57',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 779,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'West',
#   'prevailing_wage': 85854.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV58',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2825,
#   'yr_of_estab': 1996,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 14174.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV59',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3510,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 47176.84,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV60',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2624,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 4949.28,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV61',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 5340,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'West',
#   'prevailing_wage': 67410.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV62',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2311,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 58791.58,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV63',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5110,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'West',
#   'prevailing_wage': 103.2216,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV64',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1316,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 62591.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV65',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 100,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 102919.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV66',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2021,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 123468.56,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV67',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 80,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'West',
#   'prevailing_wage': 82324.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV68',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2070,
#   'yr_of_estab': 1847,
#   'region_of_employment': 'West',
#   'prevailing_wage': 5319.49,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV69',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2654,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 153019.94,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV70',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 292,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 38059.89,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV71',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1320,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 230.327,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV72',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1722,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'South',
#   'prevailing_wage': 61521.92,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV73',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3339,
#   'yr_of_estab': 1935,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 121316.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV74',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 452,
#   'yr_of_estab': 1890,
#   'region_of_employment': 'South',
#   'prevailing_wage': 122540.55,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV75',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3705,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 47170.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV76',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 85,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 330.3743,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV77',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2423,
#   'yr_of_estab': 1838,
#   'region_of_employment': 'West',
#   'prevailing_wage': 2927.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV78',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1274,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'South',
#   'prevailing_wage': 107781.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV79',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1549,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 590.0203,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV80',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 1062,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 194176.83,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV81',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 32619,
#   'yr_of_estab': 1947,
#   'region_of_employment': 'South',
#   'prevailing_wage': 102073.81,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV82',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4036,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 113882.38,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV83',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 39,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'West',
#   'prevailing_wage': 70778.82,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV84',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2359,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 84125.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV85',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 1023,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'South',
#   'prevailing_wage': 174014.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV86',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2480,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 34213.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV87',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1255,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 79813.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV88',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4455,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 113327.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV89',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2543,
#   'yr_of_estab': 1939,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 78893.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV90',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1359,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 140290.16,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV91',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2324,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 111926.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV92',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4103,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 125880.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV93',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3667,
#   'yr_of_estab': 1970,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 527.8901,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV94',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 488,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 49357.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV95',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2724,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'South',
#   'prevailing_wage': 69335.2,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV96',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1392,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 99737.18,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV97',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2573,
#   'yr_of_estab': 1977,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 91449.62,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV98',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3524,
#   'yr_of_estab': 1982,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 34494.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV99',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1847,
#   'yr_of_estab': 1977,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 395.995,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV100',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 107535,
#   'yr_of_estab': 1970,
#   'region_of_employment': 'West',
#   'prevailing_wage': 159645.51,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV101',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2227,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 28243.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV102',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 334,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 43421.88,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV103',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 224,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 80253.78,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV104',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 367,
#   'yr_of_estab': 1982,
#   'region_of_employment': 'West',
#   'prevailing_wage': 115235.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV105',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 306,
#   'yr_of_estab': 2003,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 95200.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV106',
#   'continent': 'North America',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2317,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Island',
#   'prevailing_wage': 41613.52,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV107',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 890,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 64137.41,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV108',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2002,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'South',
#   'prevailing_wage': 66295.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV109',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2903,
#   'yr_of_estab': 1943,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 97520.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV110',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2504,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 65164.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV111',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 951,
#   'yr_of_estab': 1956,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 73957.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV112',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1327,
#   'yr_of_estab': 1864,
#   'region_of_employment': 'West',
#   'prevailing_wage': 71415.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV113',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2421,
#   'yr_of_estab': 1974,
#   'region_of_employment': 'South',
#   'prevailing_wage': 87336.53,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV114',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1019,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 98966.72,
#   'unit_of_wage': 'Week',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV115',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1048,
#   'yr_of_estab': 1985,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 83503.6,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV116',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3323,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 57590.66,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV117',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 509,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 32400.2,
#   'unit_of_wage': 'Week',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV118',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2225,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 65993.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV119',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1641,
#   'yr_of_estab': 1984,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 32161.6,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV120',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1144,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 16421.37,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV121',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2334,
#   'yr_of_estab': 1971,
#   'region_of_employment': 'South',
#   'prevailing_wage': 160676.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV122',
#   'continent': 'South America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1415,
#   'yr_of_estab': 1913,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 53114.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV123',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2754,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 19176.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV124',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1099,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 204832.52,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV125',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 960,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 40256.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV126',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2750,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'West',
#   'prevailing_wage': 38841.44,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV127',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2753,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 133052.84,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV128',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 23287,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'South',
#   'prevailing_wage': 75234.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV129',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2140,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 37032.83,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV130',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4499,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 61617.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV131',
#   'continent': 'South America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2554,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 247393.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV132',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1333,
#   'yr_of_estab': 1969,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 341.0229,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV133',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 928,
#   'yr_of_estab': 1818,
#   'region_of_employment': 'South',
#   'prevailing_wage': 30570.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV134',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4289,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 19477.1,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV135',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 113282,
#   'yr_of_estab': 2011,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 164893.0,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV136',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1948,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'South',
#   'prevailing_wage': 131584.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV137',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
# ...
#   'prevailing_wage': 74635.08,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV956',
#   'continent': 'Oceania',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 17541,
#   'yr_of_estab': 1986,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 75224.53,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV957',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 581,
#   'yr_of_estab': 2014,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 74877.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV958',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 573,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'South',
#   'prevailing_wage': 62891.29,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV959',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 12692,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 115239.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV960',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5801,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 99037.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV961',
#   'continent': 'Oceania',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 363,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 97469.69,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV962',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 815,
#   'yr_of_estab': 1993,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 69825.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV963',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3944,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 276.7576,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV964',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1606,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 3435.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV965',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3323,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 32421.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV966',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 898,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 122187.35,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV967',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2619,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 62376.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV968',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 4035,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 41360.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV969',
#   'continent': 'Africa',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5707,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'West',
#   'prevailing_wage': 103813.15,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV970',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2803,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'South',
#   'prevailing_wage': 139924.14,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV971',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 142,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 32341.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV972',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5963,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 26217.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV973',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3336,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 65227.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV974',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4589,
#   'yr_of_estab': 1985,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 81132.15,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV975',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2681,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'South',
#   'prevailing_wage': 79079.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV976',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5601,
#   'yr_of_estab': 2014,
#   'region_of_employment': 'South',
#   'prevailing_wage': 132150.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV977',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 499,
#   'yr_of_estab': 1984,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 98867.47,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV978',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3716,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 311.1659,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV979',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 866,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 41439.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV980',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 394921,
#   'yr_of_estab': 1975,
#   'region_of_employment': 'South',
#   'prevailing_wage': 106460.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV981',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2444,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'West',
#   'prevailing_wage': 30497.97,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV982',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3107,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 89256.68,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV983',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2824,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'West',
#   'prevailing_wage': 95016.97,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV984',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1836,
#   'yr_of_estab': 1975,
#   'region_of_employment': 'West',
#   'prevailing_wage': 16780.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV985',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 63,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 78553.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV986',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2097,
#   'yr_of_estab': 1914,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 125702.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV987',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 444,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'West',
#   'prevailing_wage': 29951.72,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV988',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3329,
#   'yr_of_estab': 1983,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 144548.82,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV989',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 6070,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 50956.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV990',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 860,
#   'yr_of_estab': 1988,
#   'region_of_employment': 'South',
#   'prevailing_wage': 70892.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV991',
#   'continent': 'North America',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 13728,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'South',
#   'prevailing_wage': 72626.0,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV992',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2749,
#   'yr_of_estab': 1996,
#   'region_of_employment': 'South',
#   'prevailing_wage': 39114.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV993',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2595,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 142300.54,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV994',
#   'continent': 'South America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1228,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 314.2371,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV995',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 273,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 56495.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV996',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 302,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'South',
#   'prevailing_wage': 47.4872,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV997',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2294,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 109711.81,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV998',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4266,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'South',
#   'prevailing_wage': 208952.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV999',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 21013,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'West',
#   'prevailing_wage': 88780.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV1000',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 115,
#   'yr_of_estab': 1965,
#   'region_of_employment': 'South',
#   'prevailing_wage': 48947.85,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  ...]

# %%
DB_NAME = "US_VISA"
COLLECTION_Name = "visa_data"
CONNECTION_URL = "mongodb+srv://TINTUEEECEC:TINTUEEECEC@cluster0.fhypued.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_Name]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6821e945a96046619178080c'), ObjectId('6821e945a96046619178080d'), ObjectId('6821e945a96046619178080e'), ObjectId('6821e945a96046619178080f'), ObjectId('6821e945a960466191780810'), ObjectId('6821e945a960466191780811'), ObjectId('6821e945a960466191780812'), ObjectId('6821e945a960466191780813'), ObjectId('6821e945a960466191780814'), ObjectId('6821e945a960466191780815'), ObjectId('6821e945a960466191780816'), ObjectId('6821e945a960466191780817'), ObjectId('6821e945a960466191780818'), ObjectId('6821e945a960466191780819'), ObjectId('6821e945a96046619178081a'), ObjectId('6821e945a96046619178081b'), ObjectId('6821e945a96046619178081c'), ObjectId('6821e945a96046619178081d'), ObjectId('6821e945a96046619178081e'), ObjectId('6821e945a96046619178081f'), ObjectId('6821e945a960466191780820'), ObjectId('6821e945a960466191780821'), ObjectId('6821e945a960466191780822'), ObjectId('6821e945a960466191780823'), ObjectId('6821e945a960466191780824'), ObjectId('6821e945a960466191780825'), ObjectId('6821e945a960466191780826'), ObjectId('6821e945a960466191780827'), ObjectId('6821e945a960466191780828'), ObjectId('6821e945a960466191780829'), ObjectId('6821e945a96046619178082a'), ObjectId('6821e945a96046619178082b'), ObjectId('6821e945a96046619178082c'), ObjectId('6821e945a96046619178082d'), ObjectId('6821e945a96046619178082e'), ObjectId('6821e945a96046619178082f'), ObjectId('6821e945a960466191780830'), ObjectId('6821e945a960466191780831'), ObjectId('6821e945a960466191780832'), ObjectId('6821e945a960466191780833'), ObjectId('6821e945a960466191780834'), ObjectId('6821e945a960466191780835'), ObjectId('6821e945a960466191780836'), ObjectId('6821e945a960466191780837'), ObjectId('6821e945a960466191780838'), ObjectId('6821e945a960466191780839'), ObjectId('6821e945a96046619178083a'), ObjectId('6821e945a96046619178083b'), ObjectId('6821e945a96046619178083c'), ObjectId('6821e945a96046619178083d'), ObjectId('6821e945a96046619178083e'), ObjectId('6821e945a96046619178083f'), ObjectId('6821e945a960466191780840'), ObjectId('6821e945a960466191780841'), ObjectId('6821e945a960466191780842'), ObjectId('6821e945a960466191780843'), ObjectId('6821e945a960466191780844'), ObjectId('6821e945a960466191780845'), ObjectId('6821e945a960466191780846'), ObjectId('6821e945a960466191780847'), ObjectId('6821e945a960466191780848'), ObjectId('6821e945a960466191780849'), ObjectId('6821e945a96046619178084a'), ObjectId('6821e945a96046619178084b'), ObjectId('6821e945a96046619178084c'), ObjectId('6821e945a96046619178084d'), ObjectId('6821e945a96046619178084e'), ObjectId('6821e945a96046619178084f'), ObjectId('6821e945a960466191780850'), ObjectId('6821e945a960466191780851'), ObjectId('6821e945a960466191780852'), ObjectId('6821e945a960466191780853'), ObjectId('6821e945a960466191780854'), ObjectId('6821e945a960466191780855'), ObjectId('6821e945a960466191780856'), ObjectId('6821e945a960466191780857'), ObjectId('6821e945a960466191780858'), ObjectId('6821e945a960466191780859'), ObjectId('6821e945a96046619178085a'), ObjectId('6821e945a96046619178085b'), ObjectId('6821e945a96046619178085c'), ObjectId('6821e945a96046619178085d'), ObjectId('6821e945a96046619178085e'), ObjectId('6821e945a96046619178085f'), ObjectId('6821e945a960466191780860'), ObjectId('6821e945a960466191780861'), ObjectId('6821e945a960466191780862'), ObjectId('6821e945a960466191780863'), ObjectId('6821e945a960466191780864'), ObjectId('6821e945a960466191780865'), ObjectId('6821e945a960466191780866'), ObjectId('6821e945a960466191780867'), ObjectId('6821e945a960466191780868'), ObjectId('6821e945a960466191780869'), ObjectId('6821e945a96046619178086a'), ObjectId('6821e945a96046619178086b'), ObjectId('6821e945a96046619178086c'), ObjectId('6821e945a96046619178086d'), ObjectId('6821e945a96046619178086e'), ObjectId('6821e945a96046619178086f'), ObjectId('6821e945a960466191780870'), ObjectId('6821e945a960466191780871'), ObjectId('6821e945a960466191780872'), ObjectId('6821e945a960466191780873'), ObjectId('6821e945a96046619178 ...

# %%
records = collection.find()
records

# %%
df = pd.DataFrame(list(records))
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  6821e945a96046619178080c  EZYV01      Asia           High School
# 1  6821e945a96046619178080d  EZYV02      Asia              Master's
# 2  6821e945a96046619178080e  EZYV03      Asia            Bachelor's
# 3  6821e945a96046619178080f  EZYV04      Asia            Bachelor's
# 4  6821e945a960466191780810  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified
